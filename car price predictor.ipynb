# %%
import numpy as np
import pandas as pd

# %%
cars=pd.read_csv('/content/cars data.csv')

# %%
cars.head(2)
# Out:
#                                    name   company  year     Price  kms_driven  \
# 0  Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007    80,000  45,000 kms
# 1               Mahindra Jeep CL550 MDI  Mahindra  2006  4,25,000      40 kms
#
#   fuel_type
# 0    Petrol
# 1    Diesel

# %%
cars.shape
# Out:
# (892, 6)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
cars.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
cars.sample(5)
# Out:
#                                 name   company  year     Price  kms_driven  \
# 279         Renault Scala RxL Diesel   Renault  2014  3,49,999  49,000 kms
# 196             Mahindra Scorpio SLX  Mahindra  2007  3,55,000  75,000 kms
# 456          Mahindra TUV300 T4 Plus  Mahindra  2016  5,40,000  35,000 kms
# 550   Ford EcoSport Trend 1.5 Ti VCT      Ford  2017  5,80,000  10,000 kms
# 90   Toyota Corolla Altis Petrol Ltd    Toyota  2009  2,40,000  35,000 kms
#
#     fuel_type
# 279    Diesel
# 196    Diesel
# 456    Diesel
# 550    Petrol
# 90     Petrol

# %%
cars['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %%
cars.iloc[123].values
# Out:
# array(['Hyundai i20 Sportz 1.4 CRDI', 'Hyundai', '2011', '3,50,000',
#        '33,333 kms', 'Diesel'], dtype=object)

# %%
cars['fuel_type'].value_counts()
# Out:
# fuel_type
# Petrol    440
# Diesel    395
# LPG         2
# Name: count, dtype: int64

# %%
cars.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
cars['year'].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '...', '150k', 'TOUR', '2003', 'r 15', '2004', 'Zest', '/-Rs',
#        'sale', '1995', 'ara)', '2002', 'SELL', '2001', 'tion', 'odel',
#        '2 bs', 'arry', 'Eon', 'o...', 'ture', 'emi', 'car', 'able', 'no.',
#        'd...', 'SALE', 'digo', 'sell', 'd Ex', 'n...', 'e...', 'D...',
#        ', Ac', 'go .', 'k...', 'o c4', 'zire', 'cent', 'Sumo', 'cab',
#        't xe', 'EV2', 'r...', 'zest'], dtype=object)

# %%
cars['year'].value_counts()
# Out:
# year
# 2015    117
# 2014     94
# 2013     94
# 2016     76
# 2012     75
#        ...
# ture      1
# emi       1
# able      1
# no.       1
# zest      1
# Name: count, Length: 61, dtype: int64

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
cars
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
cars.dropna(inplace=True)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 837 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        837 non-null    object
#  1   company     837 non-null    object
#  2   year        837 non-null    object
#  3   Price       837 non-null    object
#  4   kms_driven  837 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 45.8+ KB

# %%
cars['fuel_type'].value_counts()
# Out:
# fuel_type
# Petrol    440
# Diesel    395
# LPG         2
# Name: count, dtype: int64

# %%
cars['year'].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '2003', '2004', '1995', '2002', '2001'], dtype=object)

# %%
cars.shape
# Out:
# (837, 6)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 837 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        837 non-null    object
#  1   company     837 non-null    object
#  2   year        837 non-null    object
#  3   Price       837 non-null    object
#  4   kms_driven  837 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 45.8+ KB

# %%
cars.isnull().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %%
cars['Price'].value_counts()
# Out:
# Price
# Ask For Price    21
# 2,50,000         16
# 3,50,000         12
# 4,00,000         11
# 1,30,000         11
#                  ..
# 7,49,999          1
# 11,30,000         1
# 10,74,999         1
# 3,24,999          1
# 5,00,001          1
# Name: count, Length: 273, dtype: int64

# %%
cars.shape
# Out:
# (837, 6)

# %%
cars=cars[cars['Price']!='Ask For Price']

# %%
cars.head()
# Out:
#                                      name   company  year     Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007    80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  4,25,000
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  5,75,000
# 6                               Ford Figo      Ford  2012  1,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel
# 6  41,000 kms    Diesel

# %%
cars['Price'].value_counts()
# Out:
# Price
# 2,50,000     16
# 3,50,000     12
# 4,00,000     11
# 1,30,000     11
# 2,10,000     10
#              ..
# 7,49,999      1
# 11,30,000     1
# 10,74,999     1
# 3,24,999      1
# 5,00,001      1
# Name: count, Length: 272, dtype: int64

# %%
cars['kms_driven']=cars['kms_driven'].str.replace('kms','')

# %%
cars['kms_driven']
# Out:
# 0        45,000
# 1            40
# 3        28,000
# 4        36,000
# 6        41,000
#          ...
# 883      50,000
# 885      30,000
# 886    1,32,000
# 888      27,000
# 889      40,000
# Name: kms_driven, Length: 816, dtype: object

# %%
cars['kms_driven']=cars['kms_driven'].str.replace(',','')

# %%
cars
# Out:
#                                        name   company  year     Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007    80,000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  4,25,000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  5,75,000
# 6                                 Ford Figo      Ford  2012  1,75,000
# ..                                      ...       ...   ...       ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  2,70,000
# 885               Tata Indica V2 DLE BS III      Tata  2009  1,10,000
# 886                    Toyota Corolla Altis    Toyota  2009  3,00,000
# 888                     Tata Zest XM Diesel      Tata  2018  2,60,000
# 889                      Mahindra Quanto C8  Mahindra  2013  3,90,000
#
#     kms_driven fuel_type
# 0       45000     Petrol
# 1          40     Diesel
# 3       28000     Petrol
# ...

# %%
cars['Price']=cars['Price'].str.replace(',','')

# %%
cars
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 6                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 885               Tata Indica V2 DLE BS III      Tata  2009  110000
# 886                    Toyota Corolla Altis    Toyota  2009  300000
# 888                     Tata Zest XM Diesel      Tata  2018  260000
# 889                      Mahindra Quanto C8  Mahindra  2013  390000
#
#     kms_driven fuel_type
# 0       45000     Petrol
# 1          40     Diesel
# 3       28000     Petrol
# 4       36000     Diesel
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        816 non-null    object
#  1   company     816 non-null    object
#  2   year        816 non-null    object
#  3   Price       816 non-null    object
#  4   kms_driven  816 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: object(6)
# memory usage: 76.9+ KB

# %%
cars['year']=cars['year'].astype(int)
cars['Price']=cars['Price'].astype(int)
cars['kms_driven']=cars['kms_driven'].astype(int)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 816 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        816 non-null    object
#  1   company     816 non-null    object
#  2   year        816 non-null    int64
#  3   Price       816 non-null    int64
#  4   kms_driven  816 non-null    int64
#  5   fuel_type   816 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 76.9+ KB

# %%
cars['fuel_type']=cars['fuel_type'].str.replace('LPG','CNG')

# %%
cars['fuel_type'].value_counts()
# Out:
# fuel_type
# Petrol    428
# Diesel    386
# CNG         2
# Name: count, dtype: int64

# %%
cars['name']=cars['name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
cars
# Out:
#                        name   company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 3         Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 6                 Ford Figo      Ford  2012  175000       41000    Diesel
# ..                      ...       ...   ...     ...         ...       ...
# 883      Maruti Suzuki Ritz    Maruti  2011  270000       50000    Petrol
# 885          Tata Indica V2      Tata  2009  110000       30000    Diesel
# 886    Toyota Corolla Altis    Toyota  2009  300000      132000    Petrol
# 888            Tata Zest XM      Tata  2018  260000       27000    Diesel
# 889      Mahindra Quanto C8  Mahindra  2013  390000       40000    Diesel
#
# [816 rows x 6 columns]

# %%
X=cars.drop(columns='Price')
y=cars['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test=train_test_split(X,y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe = OneHotEncoder()
ohe.fit(X[['name','company','fuel_type',]])
# Out:
# OneHotEncoder()

# %%
column_transfer = make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),
                                          remainder='passthrough')

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_transfer,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
# ...

# %%
y_predict=pipe.predict(X_test)

# %%
y_predict
# Out:
# array([ 1.49916738e+05, -1.74523170e+05,  2.47005799e+05,  1.91180221e+05,
#         3.54292179e+05,  2.42552274e+05,  8.08240990e+04,  5.28808359e+05,
#         1.88277353e+05,  5.79453257e+04, -3.65456533e+04,  6.81628749e+05,
#         2.59947270e+05,  2.88459856e+05,  8.05812984e+04,  2.97044016e+05,
#         7.41269677e+05, -1.20603334e+04,  3.42906700e+05,  1.48955053e+05,
#         7.01805451e+05,  5.45882388e+05,  1.28934852e+06,  6.24493734e+05,
#         7.91424383e+05,  6.93091277e+04, -7.10206261e+03,  7.76755902e+05,
#         2.23752267e+05,  4.27950371e+05,  2.07266701e+04,  4.28041105e+05,
#         5.27970019e+05,  9.75301904e+05,  3.25485330e+05, -1.50364296e+05,
#         2.19479828e+05,  5.27732701e+05,  3.80300652e+03,  1.48662653e+05,
#         6.29924162e+05,  4.30877866e+05,  4.61677658e+05,  3.92602372e+05,
#         1.68241854e+05,  5.45882388e+05,  4.95906809e+05,  2.84963300e+05,
# ...

# %%
r2_score(y_test,y_predict)
# Out:
# 0.502654463596403

# %%
scores=[]
for i in range(1000):
  X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2, random_state=i)
  lr=LinearRegression()
  pipe=make_pipeline(column_transfer,lr)
  pipe.fit(X_train,y_train)
  y_predict=pipe.predict(X_test)
  scores.append(r2_score(y_test,y_predict))

# %%
np.argmax(scores)
# Out:
# 891

# %%
scores[np.argmax(scores)]
# Out:
# 0.7873968963170417

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2, random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_transfer,lr)
pipe.fit(X_train,y_train)
y_predict=pipe.predict(X_test)
r2_score(y_test,y_predict)
# Out:
# 0.7873968963170417

# %%
pipe.predict(pd.DataFrame([['Maruti Suzuki Swift','Maruti',2019,100,'Petrol']],columns=['name','company','year','kms_driven','fuel_type']))
# Out:
# array([458144.43919154])

# %%
X.columns
# Out:
# Index(['name', 'company', 'year', 'kms_driven', 'fuel_type'], dtype='object')

# %%
def prediction(name,company,year,kms_driven,fuel_type):
  input_data=pd.DataFrame({"name":[name],"company":[company],"year":[year],"kms_driven":[kms_driven],"fuel_type":[fuel_type]})
  return pipe.predict(input_data)[0]

# %%
pip install gradio
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 76.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.2/318.2 kB 16.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 88.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 4.6 MB/s eta 0:00:00
# ...

# %%
import gradio as gr

# %%
gradio=gr.Interface(fn=prediction,inputs=["text","text","number","number","text"],outputs="number",title="car Price Prediction")
gradio.launch(debug=True)
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://4f6eddd5e6cd5f1981.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://4f6eddd5e6cd5f1981.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/queueing.py", line 536, in process_events
#     response = await route_utils.call_process_api(
# ...
